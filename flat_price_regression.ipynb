# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import cross_val_score, train_test_split

from catboost import CatBoostRegressor
from xgboost import XGBRegressor

# %%
import re

from scipy import sparse

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import sent_tokenize

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import Ridge

# %%
train_path = 'data/train.csv'
test_path = 'data/test.csv'
review_path = 'data/reviews.csv'
calendar_path = 'data/calendar.csv'

# %%
train_df = pd.read_csv(train_path)
test_df = pd.read_csv(test_path)
review_df = pd.read_csv(review_path)
calendar_df = pd.read_csv(calendar_path)

# %%
calendar_df['date'] = pd.to_datetime(calendar_df['date'])
max_date = calendar_df['date'].max()
max_date
# Out:
# Timestamp('2019-11-06 00:00:00')

# %%
review_df['date'] = pd.to_datetime(review_df['date'])
review_df['days'] = (max_date - review_df['date']).apply(lambda x: x.days)

# %% [markdown]
# # all dataset agg

# %%
train_df.loc[train_df.price <= 10, 'price'] = 10
# train_df.loc[train_df.price >= 1000, 'price'] = 1000

full_df = pd.concat([train_df, test_df])
full_df['host_since'] = pd.to_datetime(full_df['host_since'])
full_df['host_active_days'] = (max_date - full_df['host_since']).apply(lambda x: x.days)
host_list_count = full_df.groupby('host_id')['id'].count().rename('host_id_counts').reset_index()

mid_active_days = full_df['host_active_days'].median()
mid_bathrooms = full_df['bathrooms'].median()
mid_bedrooms = full_df['bedrooms'].median()
mid_beds = full_df['beds'].median()
mid_active_days, mid_bathrooms, mid_bedrooms, mid_beds
# Out:
# (1594.0, 1.0, 1.0, 1.0)

# %% [markdown]
# # name description

# %%
stop_words = set(stopwords.words('english'))
stemmer = WordNetLemmatizer()

# %%
def clean_text(text):
    # Converting to Lowercase
    text = text.lower()
    # Remove all the special characters
    text = re.sub(r'\W', ' ', text)
    # Substituting multiple spaces with single space
    text = re.sub(r'\s+', ' ', text, flags=re.I)
    # remove word less then 2 characters
    text = re.sub(r'\b\w{1,2}\b', '', text)

    tokens = word_tokenize(text)
    tokens = [stemmer.lemmatize(word) for word in tokens]
    tokens = [word for word in tokens if word not in stop_words]
    preprocessed_text = ' '.join(tokens)

    return preprocessed_text

# %%
y = train_df.price
X = train_df.drop('price', axis=1)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=23)

# %%
def lr_data_prepare(data_df, vect, f_train=True):
    amenities = (data_df['amenities'].str.replace('"', '').str.replace('{', '')
                 .str.replace('}', '').str.replace(' ', ''))
    union_text = (
        data_df['name'].fillna('unknown_name')
        + ' ' + data_df['description'].fillna('unknown_desc') 
        + ' ' + data_df['space'].fillna('unknown_space')
        + ' ' + data_df['access'].fillna('unknown_acess') 
        + ' ' + data_df['transit'].fillna('unknown_trans')
        + ' ' + data_df['neighborhood_overview'].fillna('unknown_neigh')
        + ' ' + amenities.fillna('unknown_amen')
        + ' ' + data_df['house_rules'].fillna('unknown_rules')
        + ' ' + data_df['interaction'].fillna('unknown_inter')
        + ' ' + data_df['notes'].fillna('unknown_note')
        + ' ' + data_df['host_about'].fillna('unknown_about')
    ).apply(lambda x: clean_text(x))

    
    if f_train:
        vect.fit(union_text)
    data_sparse = vect.transform(union_text)

    return data_sparse

# %%
def mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
vectorizer = TfidfVectorizer(min_df=0.01, max_df=0.7, max_features=20_000)

# %%
train_sparse = lr_data_prepare(X_train, vectorizer, f_train=True)

# %%
lr_reg = Ridge(alpha=4, random_state=23)
lr_reg.fit(train_sparse, np.log1p(y_train))
# Out:
# Ridge(alpha=4, copy_X=True, fit_intercept=True, max_iter=None, normalize=False,
#       random_state=23, solver='auto', tol=0.001)

# %%
test_sparse = lr_data_prepare(X_valid,  vectorizer, f_train=False)

# %%
mape(y_valid, np.expm1(lr_reg.predict(test_sparse)))
# Out:
# 38.63568163583526

# %%
lr_reg = Ridge(alpha=4, random_state=23)
train_sparse = lr_data_prepare(X, vectorizer, f_train=True)
lr_reg.fit(train_sparse, np.log1p(y))
# Out:
# Ridge(alpha=4, copy_X=True, fit_intercept=True, max_iter=None, normalize=False,
#       random_state=23, solver='auto', tol=0.001)

# %%
full_sparse = lr_data_prepare(full_df, vectorizer, f_train=False)

# %%
full_df['lr_pred'] = np.expm1(lr_reg.predict(full_sparse))

# %%
max(full_df['lr_pred']), min(full_df['lr_pred'])
# Out:
# (773.3101743140637, 12.49484280360154)

# %% [markdown]
# # Boosting

# %%
def agg_reviews(data_df):
    days_std = review_df.groupby('listing_id')['days'].std()
    days_mean = review_df.groupby('listing_id')['days'].median()
    review_count = review_df.groupby('listing_id')['reviewer_id'].nunique()
    grouped_df = pd.concat([review_count, days_mean, days_std], axis=1).reset_index()
    grouped_df.columns = ['id', 'rev_count', 'rev_median', 'rev_std']
    return grouped_df

# %%
agg_df = agg_reviews(review_df)

# %%
#init

property_type_set = set(['House', 'Apartment', 'Other'])
property_replace_dict = {
    'Townhouse': 'House',
    'Serviced apartment': 'Apartment',
    'Loft': 'Apartment',
    'Bungalow': 'House',
    'Cottage': 'House',
    'Villa': 'House',
    'Tiny house': 'House',
    'Earth house': 'House',
    'Chalet': 'House'  
    }

# %%
def dist_to(lat_series, long_series, to_lat, to_long):
    "return distance to center in meters"
    R = 6373000
    
    lat_1, long_1 = np.radians(to_lat),  np.radians(to_long)
    lat_2, long_2 =  np.radians(lat_series),  np.radians(long_series)

    d_lat = lat_2 - lat_1
    d_long = long_2 - long_1

    a = np.sin(d_lat / 2) ** 2 + np.cos(lat_1) * np.cos(lat_2) * np.sin(d_long / 2) ** 2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    distance = R * c
    
    return distance

# %%
def neigh_features(data_df):
    ans = []
    MAX_DIST_1 = 400
    MAX_DIST_2 = 800
    MAX_DIST_3 = 2000
    prices = data_df.price.values
    latitude = data_df.latitude.values
    longitude = data_df.longitude.values
    for ind,(_, row) in enumerate(data_df[['latitude', 'longitude']].iterrows()):
        distances = dist_to(latitude, longitude, row.latitude, row.longitude)
        distances[ind] = 10_000
        ans.append([ 
                    np.nanmedian(prices[distances < MAX_DIST_1]),
                    (distances < MAX_DIST_2).sum(), 
                    np.nanmedian(prices[distances < MAX_DIST_2]),
                    np.nanmedian(prices[distances < MAX_DIST_3]),
                    ])
    ans_df = pd.DataFrame(ans, columns=[
        f'mid_{MAX_DIST_1}_price',
        f'neigh_{MAX_DIST_2}_count', f'mid_{MAX_DIST_2}_price',
        f'mid_{MAX_DIST_3}_price',
    ])
    
    ans_df['id'] = data_df['id'].values
    return ans_df

# %%
MID_PRICE = 80.0

neigh_df = neigh_features(full_df)
neigh_df['mid_2000_price'] = neigh_df['mid_2000_price'].fillna(MID_PRICE)
neigh_df['mid_800_price'] = neigh_df['mid_800_price'].fillna(neigh_df['mid_2000_price'])
neigh_df['mid_400_price'] = neigh_df['mid_400_price'].fillna(neigh_df['mid_800_price'])
# Out:
# /Users/a18339743/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1113: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /Users/a18339743/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1116: RuntimeWarning: All-NaN slice encountered
#   overwrite_input=overwrite_input)

# %%
def make_features(data_df, vect):
    features_df = pd.DataFrame(data_df[['id', 'host_id']])
    
    host_active_days = (max_date - pd.to_datetime(data_df['host_since'])).apply(lambda x: x.days)
    features_df['host_active_days'] = host_active_days.fillna(mid_active_days).astype(int)
    
    features_df['accommodates'] = data_df.accommodates.astype(int)
    
    features_df['bathrooms'] = data_df.bathrooms.fillna(mid_bathrooms).astype(int)
    bedrooms = data_df.bedrooms.fillna(mid_bedrooms).astype(int)
    beds = data_df.beds.fillna(mid_beds).astype(int)

    features_df['guests_included'] = data_df.guests_included.astype(int)
#     features_df['beds_on_one_guest'] = (beds / data_df.guests_included).astype(int)
    features_df['bedrooms_on_one_guest'] = (bedrooms / data_df.guests_included).astype(int)
#     features_df['bathrooms_on_one_guest'] = features_df['bathrooms'] / data_df.guests_included
    
    features_df['extra_people'] = data_df.extra_people.fillna(0).astype(int)
    features_df['cleaning_fee'] = data_df.cleaning_fee.fillna(0).astype(int)
    features_df['security_deposit'] = data_df.security_deposit.fillna(0).astype(int)
    features_df['minimum_nights'] = data_df.minimum_nights.fillna(1).astype(int)
    
    features_df['cleaning_fee_by_ppl'] = (features_df['cleaning_fee'] / data_df.guests_included).astype(int)
    features_df['security_deposit_by_ppl'] = (features_df['security_deposit'] / data_df.guests_included).astype(int)
    
    features_df['id_verified'] = data_df.host_identity_verified.fillna('f') == 'f'
    # cat features

    
    #distances
    _BUCKINGHAM = (51.50057377643661, -0.143291856948126)
    _CHELSEA = (51.494652, -0.183631)
    _BRICKSTONE = (51.517750470473615, -0.09634183673107204)
    features_df['dist_to_buck'] = \
        dist_to(train_df['latitude'], train_df['longitude'], *_BUCKINGHAM)
#     features_df['dist_to_chelsea'] = \
#         dist_to(train_df['latitude'], train_df['longitude'], *_CHELSEA)
#     features_df['dist_to_brick'] = \
#         dist_to(train_df['latitude'], train_df['longitude'], *_BRICKSTONE)
    
    property_type = data_df.property_type.replace(property_replace_dict)
    property_type = property_type.apply(lambda x: x if x in property_type_set else 'Other')
    
    amenities = (data_df['amenities'].str.replace('"', '').str.replace('{', '')
                 .str.replace('}', '').str.replace(' ', '').str.lower())


    
    property_type_df = pd.get_dummies(property_type)
    room_type = pd.get_dummies(data_df.room_type)
    features_df = pd.concat([features_df, room_type, property_type_df],axis=1)

    # merge other dfs
    features_df = features_df.merge(full_df[['id', 'lr_pred']], on='id')
    features_df = features_df.merge(neigh_df.fillna(80), on='id')
    features_df = features_df.merge(agg_df, on='id', how='left')
    features_df['rev_count'] = features_df['rev_count'].fillna(0)
    features_df['rev_by_day'] = features_df['rev_count'] / features_df['host_active_days']
    features_df['rev_median'] = features_df['rev_median'].fillna(-1)
    features_df['rev_std'] = features_df['rev_std'].fillna(-1)
    features_df = features_df.merge(host_list_count, on='host_id', how='left')
    features_df['host_id_counts'] = features_df['host_id_counts']
    
#     features_df['pred_divide_mid_price'] = features_df['lr_pred'] / features_df['mid_400_price']
    
    union_text = (
        data_df['name'].fillna('unknown_name')
        + ' ' + data_df['description'].fillna('unknown_desc') 
        + ' ' + data_df['space'].fillna('unknown_space')
        + ' ' + data_df['access'].fillna('unknown_acess') 
        + ' ' + data_df['transit'].fillna('unknown_trans')
        + ' ' + data_df['neighborhood_overview'].fillna('unknown_neigh')
        + ' ' + amenities.fillna('unknown_amen')
        + ' ' + data_df['house_rules'].fillna('unknown_rules')
        + ' ' + data_df['interaction'].fillna('unknown_inter')
        + ' ' + data_df['notes'].fillna('unknown_note')
        + ' ' + data_df['host_about'].fillna('unknown_about')
    ).apply(lambda x: clean_text(x))
    
    # words ebmedings
    word_inx = np.concatenate([np.argsort(lr_reg.coef_)[::-1][:200], np.argsort(lr_reg.coef_)[:200]])
    text_features_df = pd.DataFrame(vect.transform(union_text)[:,word_inx].toarray(), 
                                    columns=[f'text_{vect.get_feature_names()[ind]}' for ind in word_inx])
    features_df = pd.concat([features_df, text_features_df], axis=1)
    
    
    return features_df.drop(['mid_400_price', 'mid_2000_price', 'id', 'host_id'], axis=1)

# %%
df = make_features(train_df, vectorizer)
X = df
y = np.log1p(train_df.price)

# %%
def multi_collinearity_heatmap(df, figsize=(11,9)):
    
    sns.set(style="white")
    corr = df.corr()
    mask = np.zeros_like(corr, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True
    f, ax = plt.subplots(figsize=figsize)
    cmap = sns.diverging_palette(220, 10, as_cmap=True)
    sns.heatmap(corr, mask=mask, cmap=cmap, center=0, square=True, 
                linewidths=.5, cbar_kws={"shrink": .5}, vmax=corr[corr != 1.0].max().max());

# %%
multi_collinearity_heatmap(X)

# %% [markdown]
# # test exper

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=23)

# %%
def mape_scorer(est, X_test, y_test):
    y_test = np.expm1(y_test)
    y_pred =  np.expm1(est.predict(X_test))
    return np.mean(np.abs((y_test - y_pred) / y_test)) * 100

# %%
regressor = CatBoostRegressor(verbose=1000, random_state=23, 
                              loss_function='MAE',
#                               cat_features=cat_features, 
                              thread_count=10,
                             )
regressor.fit(X_train, y_train)

print(mape_scorer(regressor, X_valid, y_valid))
# Out:
# 0:	learn: 0.5942803	total: 49.9ms	remaining: 49.8s
# 999:	learn: 0.2233110	total: 34.1s	remaining: 0us
# 24.158828522780528

# %%
pd.DataFrame(sorted(list(zip(regressor.get_feature_importance(), X.columns)),
                    key=lambda x: x[0], reverse=True))
# Out:
#              0                             1
# 0    22.155560                       lr_pred
# 1    16.073948               Entire home/apt
# 2     9.738431                  accommodates
# 3     8.564398                 mid_800_price
# 4     8.004840                      bedrooms
# 5     3.428491                     bathrooms
# 6     2.132402                  cleaning_fee
# 7     1.556549                  extra_people
# 8     1.274979                          beds
# 9     1.229637                minimum_nights
# 10    1.131928                  dist_to_buck
# 11    1.051041              security_deposit
# 12    1.042842                    rev_by_day
# 13    1.032114                 dist_to_brick
# 14    0.983348                host_id_counts
# 15    0.932047                  Private room
# 16    0.912760                   Shared room
# 17    0.906780               dist_to_chelsea
# 18    0.727091                     rev_count
# 19    0.709237                    rev_median
# 20    0.575794                       rev_std
# 21    0.562043               neigh_800_count
# 22    0.441560          text_airconditioning
# 23    0.432065               guests_included
# 24    0.406877                         Other
# 25    0.323103                  text_private
# 26    0.288985                  text_bedroom
# 27    0.278068            text_complimentary
# 28    0.269556                    text_suite
# 29    0.268696                     text_room
# 30    0.251303                   text_luxury
# 31    0.246717                    text_guest
# 32    0.193320              host_active_days
# 33    0.192349                     text_free
# 34    0.187971                  text_subject
# 35    0.183560               text_dishwasher
# 36    0.182659                text_luxurious
# 37    0.181051       text_translationmissing
# 38    0.175878                   text_family
# 39    0.162518                      text_bed
# 40    0.162163                   text_entire
# 41    0.155111                 text_elevator
# 42    0.147127                 text_bathroom
# 43    0.141190  text_laptopfriendlyworkspace
# 44    0.138971                   text_double
# 45    0.134811                   text_street
# 46    0.134442                      text_two
# 47    0.125882        text_privatelivingroom
# 48    0.121900                     text_lift
# 49    0.121114                text_apartment
# 50    0.121094                    text_hotel
# 51    0.116867                     text_shoe
# 52    0.116408                   text_people
# 53    0.114846                 text_hotwater
# 54    0.113882                     text_rule
# 55    0.112365                    text_adult
# 56    0.109497                         House
# 57    0.107337                 text_stunning
# 58    0.105150                  text_student
# 59    0.102287                   text_member
# 60    0.101150                    text_group
# 61    0.099322                   text_marble
# 62    0.097754                 text_property
# 63    0.097162                   text_latest
# 64    0.092290                    text_happy
# 65    0.088705                    text_house
# 66    0.088630                   text_master
# 67    0.087114                     Apartment
# 68    0.087091                     text_sofa
# 69    0.085705                    text_dryer
# 70    0.085302                   text_dining
# 71    0.083126            text_unknown_neigh
# 72    0.082332                      text_4pm
# 73    0.081895                   text_toilet
# 74    0.081549           text_smokingallowed
# 75    0.080065                 text_business
# 76    0.078699                   text_tennis
# 77    0.077898                      text_use
# 78    0.077591             text_contemporary
# 79    0.076318                   text_living
# 80    0.075355                    text_three
# 81    0.072927                      text_key
# 82    0.071835                      text_cot
# 83    0.071690                text_concierge
# 84    0.071069                text_microwave
# 85    0.070429                    text_whole
# 86    0.070112                    text_small
# 87    0.069978                  text_mayfair
# 88    0.069118                   text_agreed
# 89    0.069032                     text_crib
# 90    0.067955       text_hosting_amenity_50
# 91    0.067143                   text_single
# 92    0.066962                    text_party
# 93    0.065929            text_unknown_about
# 94    0.065348    text_freeparkingonpremises
# 95    0.065292          text_indoorfireplace
# 96    0.065250                   text_office
# 97    0.064077                text_dedicated
# 98    0.063988                     text_name
# 99    0.063241                      text_new
# 100   0.063156                     text_park
# 101   0.062240                   text_shared
# 102   0.061529                     text_line
# 103   0.061052          text_privateentrance
# 104   0.058558                    text_sleep
# 105   0.057468                 text_remember
# 106   0.057327              text_kidfriendly
# 107   0.057302               text_safetycard
# 108   0.057142                text_neighbour
# 109   0.056752                  text_checked
# 110   0.055852                     text_hyde
# 111   0.055130                      text_dog
# 112   0.053418                      text_day
# 113   0.052921                text_bedlinens
# 114   0.051672                  text_stylish
# 115   0.051435                  text_ceiling
# 116   0.050872                     text_home
# 117   0.050761                  text_bedding
# 118   0.050678                      text_kid
# 119   0.049947                   text_candle
# 120   0.048425                      text_500
# 121   0.048406        text_lockonbedroomdoor
# 122   0.048162                 text_wardrobe
# 123   0.047744                   text_minute
# 124   0.046113            text_unknown_acess
# 125   0.046029                     text_work
# 126   0.046003                text_confirmed
# 127   0.045467                 text_communal
# 128   0.045195                    text_issue
# 129   0.045185                     text_uber
# 130   0.045144                text_including
# 131   0.043727                      text_bus
# 132   0.042645                      text_non
# 133   0.041852                  text_cooking
# 134   0.041843                     text_unit
# 135   0.041623                  text_perfect
# 136   0.041134                  text_washing
# 137   0.040963                     text_cosy
# 138   0.040141                 text_strictly
# 139   0.039775                    text_range
# 140   0.038388                  text_charing
# 141   0.037975                    text_quiet
# 142   0.037451                  text_terrace
# 143   0.036734                 text_junction
# 144   0.036490                  text_walking
# 145   0.036397                 text_equipped
# 146   0.036195     text_longtermstaysallowed
# 147   0.035479                  text_arrival
# 148   0.035163                     text_send
# 149   0.034904                   text_sought
# 150   0.034436            text_cookingbasics
# 151   0.034349                  text_croydon
# 152   0.034294              text_exceptional
# 153   0.034277                text_penthouse
# 154   0.034128            text_unfortunately
# 155   0.033519                text_transport
# 156   0.033356                     text_oven
# 157   0.033161                     text_pool
# 158   0.032884                   text_access
# 159   0.031775                   text_tenant
# 160   0.031323                   text_square
# 161   0.031176              text_coffeemaker
# 162   0.031015                text_requested
# 163   0.030537               text_restaurant
# 164   0.029906                text_emergency
# 165   0.029717                     text_come
# 166   0.029187                     text_taxi
# 167   0.028623                 text_checking
# 168   0.028535                  text_bathtub
# 169   0.027486                  text_artwork
# 170   0.027080                text_furnished
# 171   0.026737   text_petsliveonthisproperty
# 172   0.026705                text_reception
# 173   0.026477              text_opportunity
# 174   0.025891                  text_holiday
# 175   0.025691              text_westminster
# 176   0.025056                text_highchair
# 177   0.024848                    text_fresh
# 178   0.024720                  text_message
# 179   0.024478                     text_four
# 180   0.024222              text_beautifully
# 181   0.024210                  text_hosting
# 182   0.023860                      text_hen
# 183   0.023403                      text_pet
# 184   0.023290                text_stratford
# 185   0.023061                  text_feature
# 186   0.022477                     text_desk
# 187   0.022466                 text_boutique
# 188   0.022420                text_carefully
# 189   0.022132                     text_team
# 190   0.022072                  text_license
# 191   0.021738                    text_tesco
# 192   0.021554                    text_share
# 193   0.021186                 text_designed
# 194   0.020954                    text_incur
# 195   0.020890                  text_elegant
# 196   0.020780                   id_verified
# 197   0.020365                    text_pride
# 198   0.020195                text_adventure
# 199   0.019985                  text_deposit
# 200   0.019234                   text_lovely
# 201   0.019219                  text_cabletv
# 202   0.019194           text_recommendation
# 203   0.018366                     text_stop
# 204   0.018167                     text_much
# 205   0.017894                 text_interior
# 206   0.017355                  text_chelsea
# 207   0.017091                    text_every
# 208   0.017064              text_supermarket
# 209   0.017028             text_conditioning
# 210   0.016724                     text_bath
# 211   0.016526                   text_advice
# 212   0.016460                   text_covent
# 213   0.016396                   text_social
# 214   0.016332                   text_centre
# 215   0.016258                 text_upmarket
# 216   0.016211                    text_clean
# 217   0.015954                 text_friendly
# 218   0.015932                  text_earlier
# 219   0.015868        text_freestreetparking
# 220   0.015856                text_liverpool
# 221   0.015497                  text_cuisine
# 222   0.015261                   text_highly
# 223   0.015226                    text_fully
# 224   0.014926                 text_midnight
# 225   0.014873               text_connection
# 226   0.014598                  text_largest
# 227   0.014448                 text_accessed
# 228   0.014069                 text_wireless
# 229   0.013797                   text_fridge
# 230   0.013498                      text_fit
# 231   0.013473             text_cosmopolitan
# 232   0.013410                 text_affluent
# 233   0.013338                 text_expected
# 234   0.013319                    text_train
# 235   0.013204                     text_week
# 236   0.012932                    text_nplay
# 237   0.012912                 text_inviting
# 238   0.012649                     text_tidy
# 239   0.012443               text_playground
# 240   0.012321                    text_heart
# 241   0.012262                    text_agent
# 242   0.012177                      text_300
# 243   0.012065                   text_iconic
# 244   0.011894                    text_night
# 245   0.011698               text_occupation
# 246   0.011649                     text_soho
# 247   0.011434                     text_live
# 248   0.011388                    text_cheap
# 249   0.011370               text_marylebone
# 250   0.011090               text_buckingham
# 251   0.010866                   text_accept
# 252   0.010676                    text_young
# 253   0.010445       text_ethernetconnection
# 254   0.010326                 text_clothing
# 255   0.010127                      text_gbp
# 256   0.009986                    text_count
# 257   0.009791                   text_border
# 258   0.009721                   text_common
# 259   0.009548                     text_wash
# 260   0.009455                    text_grand
# 261   0.009336                  text_visitor
# 262   0.009163                 text_customer
# 263   0.008898                    text_oasis
# 264   0.008837                     text_soon
# 265   0.008785                  text_minimum
# 266   0.008696                   text_closet
# 267   0.008507                  text_hackney
# 268   0.008476                   text_retail
# 269   0.008412                   text_regent
# 270   0.008313                    text_north
# 271   0.008189                  text_seating
# 272   0.008152                text_sometimes
# 273   0.008139                   text_island
# 274   0.007922                 text_reliable
# 275   0.007919                     text_post
# 276   0.007895                   text_colour
# 277   0.007881                     text_solo
# 278   0.007876                      text_toy
# 279   0.007135                  text_example
# 280   0.007108                   text_screen
# 281   0.006910                      text_guy
# 282   0.006529                   text_anyone
# 283   0.006481                text_wonderful
# 284   0.006422               text_atmosphere
# 285   0.006347                     text_pack
# 286   0.006316                  text_listing
# 287   0.006297                 text_accepted
# 288   0.006121                      text_dlr
# 289   0.006088              text_recommended
# 290   0.006047                   text_easier
# 291   0.006020                text_regarding
# 292   0.006009                    text_prime
# 293   0.005931                  text_utility
# 294   0.005888                  text_benefit
# 295   0.005441                    text_fancy
# 296   0.005389                     text_meal
# 297   0.005312                 text_promptly
# 298   0.005289                  text_profile
# 299   0.005137                   text_unique
# 300   0.005035                      text_apt
# 301   0.004961            text_communication
# 302   0.004776                     text_2011
# 303   0.004739                   text_person
# 304   0.004655                     text_girl
# 305   0.004618                text_townhouse
# 306   0.004517               text_pocketwifi
# 307   0.004502                    text_level
# 308   0.004454                      text_ask
# 309   0.004424                 text_industry
# 310   0.004255                  text_commute
# 311   0.004210                    text_quite
# 312   0.004177                    text_store
# 313   0.004080                text_broadband
# 314   0.003903               text_affordable
# 315   0.003816               text_travelcrib
# 316   0.003741               text_university
# 317   0.003718                   text_sister
# 318   0.003639                      text_bbq
# 319   0.003600                   text_cereal
# 320   0.003598                     text_foam
# 321   0.003558                    text_going
# 322   0.003474                      text_24h
# 323   0.003363                  text_storage
# 324   0.003350                  text_waiting
# 325   0.003332                   text_budget
# 326   0.003056                     text_star
# 327   0.002986                      text_low
# 328   0.002930                   text_duplex
# 329   0.002740                  text_sharing
# 330   0.002695                   text_advise
# 331   0.002561                text_perfectly
# 332   0.002492                   text_refund
# 333   0.002490                  text_mansion
# 334   0.002484                  text_doorman
# 335   0.002420                    text_study
# 336   0.002391                    text_apply
# 337   0.002377                  text_limited
# 338   0.002136                  text_holland
# 339   0.002072                   text_harrod
# 340   0.002006                   text_raised
# 341   0.001901                text_otherwise
# 342   0.001837                    text_snack
# 343   0.001824                     text_move
# 344   0.001816                    text_comfy
# 345   0.001760                    text_tiled
# 346   0.001691                   text_indian
# 347   0.001645                     text_5min
# 348   0.001525                   text_nature
# 349   0.001464              text_reservation
# 350   0.001411                   text_infant
# 351   0.001408               text_especially
# 352   0.001169              text_significant
# 353   0.001137                     text_bond
# 354   0.001131                 text_armchair
# 355   0.001121                  text_pimlico
# 356   0.001092                    text_speak
# 357   0.001087                    text_duvet
# 358   0.001008                     text_fish
# 359   0.000914                   text_female
# 360   0.000881               text_adventurer
# 361   0.000818                     text_lake
# 362   0.000803                text_sainsbury
# 363   0.000773                  text_teacher
# 364   0.000717                    text_5mins
# 365   0.000704                 text_schedule
# 366   0.000562                      text_7am
# 367   0.000523                 text_eurostar
# 368   0.000078          text_darkeningshades
# 369   0.000000                      text_mew
# 370   0.000000            text_knightsbridge
# 371   0.000000             text_entertaining
# 372   0.000000                text_fireplace
# 373   0.000000                    text_arise
# 374   0.000000                      text_hop
# 375   0.000000               text_gloucester
# 376   0.000000                   text_locked
# 377   0.000000                      text_six
# 378   0.000000                  text_sitting
# 379   0.000000                text_extensive
# 380   0.000000                    text_sleek
# 381   0.000000                    text_skill
# 382   0.000000                 text_primrose
# 383   0.000000                  text_product
# 384   0.000000                 text_spending
# 385   0.000000                   text_system
# 386   0.000000                  text_smaller
# 387   0.000000                  text_cricket
# 388   0.000000                 text_selected
# 389   0.000000                 text_culinary
# 390   0.000000                  text_receive
# 391   0.000000                      text_mod
# 392   0.000000                    text_truly
# 393   0.000000                      text_zoo
# 394   0.000000                 text_finished
# 395   0.000000                  text_butcher
# 396   0.000000                 text_landmark
# 397   0.000000                     text_game
# 398   0.000000                    text_coach
# 399   0.000000                text_housemate
# 400   0.000000                     text_chat
# 401   0.000000                 text_daughter
# 402   0.000000               text_background
# 403   0.000000                      text_map
# 404   0.000000             text_heighttoilet
# 405   0.000000                 text_everyday
# 406   0.000000                   text_smoker
# 407   0.000000               text_originally
# 408   0.000000                      text_bnb
# 409   0.000000                  text_mention
# 410   0.000000                      text_son
# 411   0.000000                   text_forest
# 412   0.000000                 text_watching
# 413   0.000000                text_welcoming
# 414   0.000000                     text_hang
# 415   0.000000                    text_chill
# 416   0.000000                  text_railway
# 417   0.000000                    text_bring
# 418   0.000000                  text_tooting
# 419   0.000000                   text_proper
# 420   0.000000                    text_canal
# 421   0.000000                   text_oyster
# 422   0.000000                     text_info
# 423   0.000000                  text_helpful
# 424   0.000000                     text_kind
# 425   0.000000                   text_except
# 426   0.000000                     text_face
# 427   0.000000                  text_finding

# %% [markdown]
# # cross val

# %%
regressor = CatBoostRegressor(verbose=1000, random_state=23, loss_function='MAE',
#                               cat_features=cat_features, 
                              thread_count=10,
                             )

# %%
score = cross_val_score(regressor, X, y, scoring=mape_scorer, cv=5)

print(f"score mean= {score.mean():.3f}, std={score.std():.3f}, {score}")
# Out:
# 0:	learn: 0.6000151	total: 8.97ms	remaining: 8.96s
# 999:	learn: 0.2252048	total: 6.54s	remaining: 0us
# 0:	learn: 0.5970550	total: 9.85ms	remaining: 9.84s
# 999:	learn: 0.2266754	total: 8.37s	remaining: 0us
# 0:	learn: 0.5927662	total: 11ms	remaining: 10.9s
# 999:	learn: 0.2238265	total: 7.88s	remaining: 0us
# 0:	learn: 0.5917784	total: 9.18ms	remaining: 9.17s
# 999:	learn: 0.2267092	total: 7.77s	remaining: 0us
# 0:	learn: 0.5955605	total: 9.66ms	remaining: 9.65s
# 999:	learn: 0.2261515	total: 7.88s	remaining: 0us
# score mean= 25.549, std=1.599, [24.04699644 25.25507219 28.2355387  23.91279338 26.29310782]

# %% [markdown]
# # submition

# %%
regressor.fit(X, y)
# Out:
# 0:	learn: 0.5959557	total: 59.1ms	remaining: 59s
# 999:	learn: 0.2256016	total: 39.5s	remaining: 0us

# %%
X_test_features = make_features(test_df)

y_test = regressor.predict(X_test_features)
submition_df = pd.DataFrame(test_df['id'])
submition_df['price'] = np.expm1(y_test)
submition_df.to_csv('submit.csv', index=False)
train_df.price.median(), train_df.price.std(), submition_df.price.median(), submition_df.price.std()
# Out:
# (80.0, 201.59477087683024, 71.76195326915621, 61.424159023721906)

# %%
# !head 'submit.csv'
# Out:
# id,price
# 9554,28.43516497570186
# 11076,62.119209988808166
# 13913,45.98813817889058
# 17402,198.72996538046996
# 24328,120.05334453166778
# 25023,82.54987977174932
# 25123,33.68372376440658
# 26223,126.83074210305953
# 26682,48.70221324078447
